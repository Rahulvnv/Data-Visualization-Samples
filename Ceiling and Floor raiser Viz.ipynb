# %%
from statsbombpy import sb
import pandas as pd
import numpy as np
import mplsoccer as mps
import matplotlib.pyplot as plt
from mplsoccer import add_image
from PIL import Image
import matplotlib.patheffects as path_effects
from urllib.request import urlopen
from highlight_text import fig_text
from copy import deepcopy
from adjustText import adjust_text

# %%
path_eff=[path_effects.Stroke(linewidth=3,foreground="black"),path_effects.Normal()]

# %%
pd.set_option("display.max_columns",150)
pd.set_option("display.max_rows",550)

# %%
it=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/serie a pass.xlsx")
ger=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/bliga pass.xlsx")
ger1=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/bliga poss.xlsx")
ger2=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/bliga sho.xlsx")

# %%
ger2
# Out:
#       Rk                     Player   Nation    Pos           Squad     Age  \
# 0      1            Paxten Aaronson   us USA  MF,DF  Eint Frankfurt  19-270
# 1      2             Sargis Adamyan   am ARM  FW,MF            Köln  30-000
# 2      3              Karim Adeyemi   de GER  FW,MF        Dortmund  21-125
# 3      4                 Amine Adli   fr FRA  FW,MF      Leverkusen  23-013
# 4      5                  Felix Agu   de GER  DF,FW   Werder Bremen  23-238
# 5      6           Naouirou Ahamada   fr FRA     MF       Stuttgart  21-055
# 6      7            Ludovic Ajorque   fr FRA  FW,MF        Mainz 05  29-087
# 7      8             Kevin Akpoguma   ng NGA     DF      Hoffenheim  28-034
# 8      9               Lucas Alario   ar ARG  FW,MF  Eint Frankfurt  30-227
# 9     10              Faride Alidou   de GER  DF,MF  Eint Frankfurt  21-309
# 10    11       Éder Álvarez Balanta   co COL  MF,FW      Schalke 04  30-084
# ...

# %%
esp=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/la liga pass.xlsx")
esp1=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/la liga poss.xlsx")
esp2=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/la liga sho.xlsx")

# %%
it1=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/serie a poss.xlsx")

# %%
fr=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/Ligue 1 pass.xlsx")
fr1=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/Ligue 1 poss.xlsx")
it2=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/serie a sho.xlsx")
fr2=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/Ligue 1 sho.xlsx")

# %%
eng=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/epl pass.xlsx")
eng1=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/epl poss.xlsx")

# %%
eng2=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/Leagues Excels/epl sho.xlsx")

# %%
for i in range(it.columns.size):
    if i<=7:
        continue
    it[it.columns[i]]=it[it.columns[i]].divide(it[it.columns[7]]).round(2)

# %%
for i in range(it1.columns.size):
    if i<=7:
        continue
    it1[it1.columns[i]]=it1[it1.columns[i]].divide(it1[it1.columns[7]]).round(2)

# %%
for i in range(it2.columns.size):
    if i<=7:
        continue
    it2[it2.columns[i]]=it2[it2.columns[i]].divide(it2[it2.columns[7]]).round(2)

# %%
for i in range(fr.columns.size):
    if i<=7:
        continue
    fr[fr.columns[i]]=fr[fr.columns[i]].divide(fr[fr.columns[7]]).round(2)

# %%
for i in range(fr1.columns.size):
    if i<=7:
        continue
    fr1[fr1.columns[i]]=fr1[fr1.columns[i]].divide(fr1[fr1.columns[7]]).round(2)

# %%
for i in range(fr2.columns.size):
    if i<=7:
        continue
    fr2[fr2.columns[i]]=fr2[fr2.columns[i]].divide(fr2[fr2.columns[7]]).round(2)

# %%
for i in range(eng.columns.size):
    if i<=7:
        continue
    eng[eng.columns[i]]=eng[eng.columns[i]].divide(eng[eng.columns[7]]).round(2)

# %%
for i in range(eng1.columns.size):
    if i<=7:
        continue
    eng1[eng1.columns[i]]=eng1[eng1.columns[i]].divide(eng1[eng1.columns[7]]).round(2)

# %%
for i in range(eng2.columns.size):
    if i<=7:
        continue
    eng2[eng2.columns[i]]=eng2[eng2.columns[i]].divide(eng2[eng2.columns[7]]).round(2)

# %%
for i in range(esp.columns.size):
    if i<=7:
        continue
    esp[esp.columns[i]]=esp[esp.columns[i]].divide(esp[esp.columns[7]]).round(2)

# %%
for i in range(esp1.columns.size):
    if i<=7:
        continue
    esp1[esp1.columns[i]]=esp1[esp1.columns[i]].divide(esp1[esp1.columns[7]]).round(2)

# %%
for i in range(esp2.columns.size):
    if i<=7:
        continue
    esp2[esp2.columns[i]]=esp2[esp2.columns[i]].divide(esp2[esp2.columns[7]]).round(2)

# %%
for i in range(ger.columns.size):
    if i<=7:
        continue
    ger[ger.columns[i]]=ger[ger.columns[i]].divide(ger[ger.columns[7]]).round(2)

# %%
for i in range(ger1.columns.size):
    if i<=7:
        continue
    ger1[ger1.columns[i]]=ger1[ger1.columns[i]].divide(ger1[ger1.columns[7]]).round(2)

# %%
for i in range(ger2.columns.size):
    if i<=7:
        continue
    ger2[ger2.columns[i]]=ger2[ger2.columns[i]].divide(ger2[ger2.columns[7]]).round(2)

# %%
eng2
# Out:
#       Rk                     Player   Nation    Pos            Squad     Age  \
# 0      1           Brenden Aaronson   us USA  MF,FW     Leeds United  22-213
# 1      2                  Che Adams  sct SCO     FW      Southampton  26-314
# 2      3                Tyler Adams   us USA     MF     Leeds United  24-098
# 3      4           Tosin Adarabioyo  eng ENG     DF           Fulham  25-241
# 4      5               Nayef Aguerd   ma MAR     DF         West Ham  27-054
# 5      6           Naouirou Ahamada   fr FRA  MF,FW   Crystal Palace  21-055
# 6      7            Rayan Aït Nouri   dz ALG     DF           Wolves  21-351
# 7      8            Kristoffer Ajer   no NOR     DF        Brentford  25-036
# 8      9              Manuel Akanji   ch SUI     DF  Manchester City  27-308
# 9     10                 Nathan Aké   nl NED     DF  Manchester City  28-094
# 10    11            Marc Albrighton  eng ENG  FW,MF   Leicester City  33-186
# ...

# %%
it1
# Out:
#       Rk                    Player   Nation    Pos          Squad     Age  \
# 0      1            James Abankwah   ie IRL     DF        Udinese  19-127
# 1      2         Oliver Abildgaard   dk DEN     MF  Hellas Verona  26-347
# 2      3             Tammy Abraham  eng ENG     FW           Roma  25-233
# 3      4          Christian Acella   it ITA     MF      Cremonese  20-320
# 4      5          Francesco Acerbi   it ITA     DF          Inter  35-102
# 5      6               Yacine Adli   fr FRA  MF,FW          Milan  22-298
# 6      7          Michel Aebischer   ch SUI  FW,MF        Bologna  26-137
# 7      8          Felix Afena-Gyan   gh GHA  FW,MF      Cremonese  20-124
# 8      9             Kevin Agudelo   co COL  MF,FW         Spezia  24-190
# 9     10                  Ola Aina   ng NGA     DF         Torino  26-227
# 10    11             Emanuel Aiwum   at AUT     DF      Cremonese  22-149
# 11    12    Jean-Daniel Akpa-Akpro   ci CIV     MF         Empoli  30-224
# ...

# %%
it1["floor"]=it1["Live"]+ it1["PrgC"]+ it["PrgP"]

# %%
fr1["floor"]=fr1["Live"]+ fr1["PrgC"]+ fr["PrgP"]
eng1["floor"]=eng1["Live"]+ eng1["PrgC"]+ eng["PrgP"]
esp1["floor"]=esp1["Live"]+ esp1["PrgC"]+ esp["PrgP"]
ger1["floor"]=ger1["Live"]+ ger1["PrgC"]+ ger["PrgP"]

# %%
tot1=pd.concat([it1,fr1,esp1,ger1])

# %%
tot=pd.concat([tot1,eng1])

# %%
tot=tot.reset_index()

# %%
it2
# Out:
#       Rk                    Player   Nation    Pos          Squad     Age  \
# 0      1            James Abankwah   ie IRL     DF        Udinese  19-127
# 1      2         Oliver Abildgaard   dk DEN     MF  Hellas Verona  26-347
# 2      3             Tammy Abraham  eng ENG     FW           Roma  25-233
# 3      4          Christian Acella   it ITA     MF      Cremonese  20-320
# 4      5          Francesco Acerbi   it ITA     DF          Inter  35-102
# 5      6               Yacine Adli   fr FRA  MF,FW          Milan  22-298
# 6      7          Michel Aebischer   ch SUI  FW,MF        Bologna  26-137
# 7      8          Felix Afena-Gyan   gh GHA  FW,MF      Cremonese  20-124
# 8      9             Kevin Agudelo   co COL  MF,FW         Spezia  24-190
# 9     10                  Ola Aina   ng NGA     DF         Torino  26-227
# 10    11             Emanuel Aiwum   at AUT     DF      Cremonese  22-149
# 11    12    Jean-Daniel Akpa-Akpro   ci CIV     MF         Empoli  30-224
# ...

# %%
it1["ceiling"]=it1["Att Pen"]+ it1["PrgR"]+ it2["npxG/Sh"]
fr1["ceiling"]=fr1["Att Pen"]+ fr1["PrgR"]+ fr2["npxG/Sh"]
eng1["ceiling"]=eng1["Att Pen"]+ eng1["PrgR"]+ eng2["npxG/Sh"]
ger1["ceiling"]=ger1["Att Pen"]+ ger1["PrgR"]+ ger2["npxG/Sh"]
esp1["ceiling"]=esp1["Att Pen"]+ esp1["PrgR"]+ esp2["npxG/Sh"]

# %%
tot1=pd.concat([it1,fr1,esp1,ger1])

# %%
tot=pd.concat([tot1,eng1])

# %%
tot=tot.reset_index()

# %%
tot
# Out:
#       index   Rk                 Player   Nation Pos            Squad     Age  \
# 0         0    1         James Abankwah   ie IRL  DF          Udinese  19-127
# 1         1    2      Oliver Abildgaard   dk DEN  MF    Hellas Verona  26-347
# 2         2    3          Tammy Abraham  eng ENG  FW             Roma  25-233
# 3         3    4       Christian Acella   it ITA  MF        Cremonese  20-320
# 4         4    5       Francesco Acerbi   it ITA  DF            Inter  35-102
# ...     ...  ...                    ...      ...  ..              ...     ...
# 2490    494  495  Crysencio Summerville   nl NED  FW     Leeds United  21-205
# 2491    495  496           Sam Surridge  eng ENG  FW  Nott'ham Forest  24-299
# 2492    496  497        Japhet Tanganga  eng ENG  DF        Tottenham  24-053
# 2493    497  498           Matt Targett  eng ENG  DF    Newcastle Utd  27-247
# 2494    498  499        James Tarkowski  eng ENG  DF          Everton  30-185
#
# ...

# %%
tot[tot["Player"].str.contains("Guim")]
# Out:
#       index   Rk           Player  Nation Pos          Squad     Age  Born  \
# 2206    210  211  Bruno Guimarães  br BRA  MF  Newcastle Utd  25-188  1997
#
#        90s  Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd  Att Pen  Live   Att  \
# 2206  29.3     67.1     1.91     12.8     35.9    19.39     1.67  67.1  3.14
#
#       Succ  Succ%  Tkld  Tkld%  Carries  TotDist  PrgDist  PrgC  \
# 2206  1.54   1.67  0.89   0.97    44.23   242.94    97.27  1.33
#
#       2023-03-01 00:00:00   CPA  Mis   Dis    Rec  PrgR  floor  ceiling
# 2206                  1.6  0.14  1.5  2.01  50.31   1.4   75.8     3.07

# %%
tot[tot["Player"].str.contains("Botman")]
# Out:
#       index  Rk       Player  Nation Pos          Squad     Age  Born   90s  \
# 2058     62  63  Sven Botman  nl NED  DF  Newcastle Utd  23-131  2000  33.7
#
#       Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd  Att Pen   Live   Att  Succ  \
# 2058    59.79     9.55    33.98    23.29     2.82     1.57  59.79  0.03  0.03
#
#       Succ%  Tkld  Tkld%  Carries  TotDist  PrgDist  PrgC  \
# 2058   2.97   0.0    0.0    33.59   151.13     79.7  0.24
#
#       2023-03-01 00:00:00   CPA   Mis   Dis    Rec  PrgR  floor  ceiling
# 2058                 0.15  0.06  0.27  0.06  38.81  0.15  62.55     1.72

# %%
tot[tot["Player"].str.contains("Isak")]
# Out:
#       index   Rk          Player  Nation Pos          Squad     Age  Born  \
# 239     239  240       Isak Hien  se SWE  DF  Hellas Verona  24-130  1999
# 1254    256  257  Alexander Isak  se SWE  FW  Real Sociedad  23-244  1999
# 2231    235  236  Alexander Isak  se SWE  FW  Newcastle Utd  23-244  1999
#
#        90s  Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd  Att Pen   Live   Att  \
# 239   27.0    47.37     5.93    27.89    18.37     1.74     0.48  47.37  1.07
# 1254   1.7    27.06     1.76     2.94    11.18    12.94     6.47  27.06  2.94
# 2231  15.9    34.78     0.63     1.89    11.70    21.82     5.79  34.65  4.03
#
#       Succ  Succ%  Tkld  Tkld%  Carries  TotDist  PrgDist  PrgC  \
# 239   0.52   1.79  0.41   1.40    21.52    96.30    45.37  0.59
# 1254  1.18  23.53  1.76  35.29    17.06   125.88    42.35  1.76
# 2231  1.89   2.95  1.64   2.55    22.08   146.54    75.79  2.45
#
#       2023-03-01 00:00:00   CPA   Mis   Dis    Rec  PrgR  floor  ceiling
# ...

# %%
tot[tot["Player"].str.contains("Joelinton")]
# Out:
#       index   Rk     Player  Nation    Pos          Squad     Age  Born   90s  \
# 2242    246  247  Joelinton  br BRA  MF,FW  Newcastle Utd  26-282  1996  29.6
#
#       Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd  Att Pen   Live   Att  Succ  \
# 2242    57.53      2.4    10.54    28.78    18.99     3.24  57.53  3.75  1.79
#
#       Succ%  Tkld  Tkld%  Carries  TotDist  PrgDist  PrgC  \
# 2242   1.61  1.42   1.28     30.3   163.95    77.23  2.16
#
#       2023-03-01 00:00:00   CPA   Mis   Dis    Rec  PrgR  floor  ceiling
# 2242                 1.52  0.44  2.43  1.72  37.67  5.07  64.08     8.31

# %%
tot[tot["Squad"]=="Newcastle Utd"]
# Out:
#       index   Rk               Player   Nation    Pos          Squad     Age  \
# 2012     16   17       Miguel Almirón   py PAR     FW  Newcastle Utd  29-102
# 2016     20   21      Elliot Anderson  sct SCO  MF,FW  Newcastle Utd  20-198
# 2058     62   63          Sven Botman   nl NED     DF  Newcastle Utd  23-131
# 2068     72   73             Dan Burn  eng ENG     DF  Newcastle Utd  31-014
# 2141    145  146      Martin Dúbravka   sk SVK     GK  Newcastle Utd  34-128
# 2176    180  181          Ryan Fraser  sct SCO     FW  Newcastle Utd  29-088
# 2197    201  202       Anthony Gordon  eng ENG  FW,MF  Newcastle Utd  22-088
# 2206    210  211      Bruno Guimarães   br BRA     MF  Newcastle Utd  25-188
# 2231    235  236       Alexander Isak   se SWE     FW  Newcastle Utd  23-244
# 2242    246  247            Joelinton   br BRA  MF,FW  Newcastle Utd  26-282
# 2272    276  277          Emil Krafth   se SWE     DF  Newcastle Utd  28-294
# ...

# %%
tot=tot[tot["90s"]>10]

# %%
tot[tot["floor"]>300]

# %%
pogurl="https://www.footyrenders.com/render/bruno-guimaraes-5-390x522.png"
pog=Image.open(urlopen(pogurl))
admurl="https://www.footyrenders.com/render/angel-di-maria-26-108x180.png"
adm=Image.open(urlopen(admurl))
dv9url="https://www.footyrenders.com/render/dusan-vlahovic-9-92x180.png"
dv9=Image.open(urlopen(dv9url))
fc7url="https://www.footyrenders.com/render/alexander-isak-8-349x540.png"
fc7=Image.open(urlopen(fc7url))
depay=Image.open(urlopen('https://resources.premierleague.com/premierleague/photos/players/250x250/p180974.png'))
kosticurl="https://resources.premierleague.com/premierleague/photos/players/250x250/p220237.png"
kostic=Image.open(urlopen(kosticurl))
milikurl="https://resources.premierleague.com/premierleague/photos/players/250x250/p179018.png"
milik=Image.open(urlopen(milikurl))

# %%
tot[tot["Player"]=="Alexander Isak"]
# Out:
#       index   Rk          Player  Nation Pos          Squad     Age  Born  \
# 2231    235  236  Alexander Isak  se SWE  FW  Newcastle Utd  23-244  1999
#
#        90s  Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd  Att Pen   Live   Att  \
# 2231  15.9    34.78     0.63     1.89     11.7    21.82     5.79  34.65  4.03
#
#       Succ  Succ%  Tkld  Tkld%  Carries  TotDist  PrgDist  PrgC  \
# 2231  1.89   2.95  1.64   2.55    22.08   146.54    75.79  2.45
#
#       2023-03-01 00:00:00   CPA   Mis   Dis    Rec  PrgR  floor  ceiling
# 2231                 1.95  1.26  2.33  1.51  25.97  7.42  39.93    13.22

# %%
fig = plt.figure(figsize=(25,14))
fig.patch.set_facecolor('#E0EEEE')
fig.patch.set_alpha(0.6)
ax = fig.add_subplot(111)
ax.patch.set_facecolor('#E0EEEE')
ax.patch.set_alpha(1.0)
ax.text(100,21,"Floor Raiser: Elevate a side by \n Demanding more ball,\n optimized decision maker\n and executor",color="black",size="15")
ax.text(100,17.5,"Ceiling Raiser: More concerned with \nabilities like movement,\n often an outlet\n for creators, \nmake good teams even better",color="black",size="15")

plt.xlabel("Floor Raiser ------>",color="black",fontsize=15)
plt.ylabel("Ceiling Rasier ------->",color="black",fontsize=15)
x=tot[(tot["floor"]<200)]["floor"]
y=tot[(tot["floor"]<200)]["ceiling"]
plt.scatter(x,y,color="cyan",edgecolor="black",label="Players across Europe",s=90,alpha=0.3)
x2=tot[(tot["Player"]=="Bruno Guimarães")| (tot["Player"]=="Sven Botman")|(tot["Player"]=="Alexander Isak")]["floor"]
y2=tot[(tot["Player"]=="Bruno Guimarães")|(tot["Player"]=="Sven Botman")|(tot["Player"]=="Alexander Isak")]["ceiling"]
s2=tot[(tot["Player"]=="Bruno Guimarães")|(tot["Player"]=="Sven Botman")|(tot["Player"]=="Alexander Isak")]["Player"]
plt.scatter(x2,y2,color="#FF69B4",edgecolor="black",label="Newcastle Players",s=180)
plt.scatter([64.08,54.38],[8.31,14.65],color="#FF69B4",edgecolor="black",s=180)
x3=[64.08,54.38]
y3=[8.31,14.65]
s3=["Joelinton","Almiron"]
texts2=[]
for x3, y3, s3 in zip(x3, y3,s3):
    texts2.append(plt.text(x3, y3, s3, size=15,color="black"))
adjust_text(texts2, only_move={'points':'y', 'texts':'y'},arrowprops=dict(arrowstyle="-", color='k', lw=1),save_steps=False)
x1=tot[(tot["ceiling"]>90) | (tot["floor"]>20)|(tot["floor"]<200)]["floor"]
y1=tot[(tot["ceiling"]>90) | (tot["floor"]>20)|(tot["floor"]<200)]["ceiling"]
s1=tot[(tot["ceiling"]>90) | (tot["floor"]>20)|(tot["floor"]>200)]["Player"]
texts=[]
for x2, y2, s2 in zip(x2, y2,s2):
    texts.append(plt.text(x2, y2, s2, size=15,color="black"))
adjust_text(texts, only_move={'points':'y', 'texts':'y'},arrowprops=dict(arrowstyle="-", color='k', lw=1),save_steps=False)
plt.title("Floor Raisers vs Ceiling Raisers - Newcastle Version (made by @Rahulvn5)",color="white",fontsize=25,path_effects=path_eff)
plt.plot([75.8,105.43],[3.07,5.41],color="red")

plt.plot([64.28,50.43],[8.28,8.28],color="red")
plt.plot([62.25,110.43],[1.72,1.3],color="red")
plt.plot([50.43,33.43],[8.28,5.28],color="red")
plt.plot([54,31.43],[14.65,8.86],color="red")
plt.legend(facecolor="white")
newax = fig.add_axes([0.1,0.27,1.32,0.15])
newax.imshow(pog)
newax.axis('off')

newax3 = fig.add_axes([0.1,0.5,0.2,0.15])
newax3.imshow(fc7)
newax3.axis('off')
newax4 = fig.add_axes([0.1,0.18,1.45,0.17])
newax4.imshow(kostic)
newax4.axis('off')
newax5 = fig.add_axes([0.1,0.15,0.25,0.15])
newax5.imshow(depay)
newax5.axis('off')
newax6 = fig.add_axes([0.1,0.3,0.2,0.15])
newax6.imshow(milik)
newax6.axis('off')
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %%
new=pd.read_excel("C:/Users/Rahul/Downloads/serie a pass 22-23.xlsx")

# %%
new1=pd.read_excel("C:/Users/Rahul/Downloads/serie a 22-23 sho.xlsx")

# %%
new=new.drop(["Matches"],axis=1)
new1=new1.drop(["Matches"],axis=1)

# %%
new

# %%
new=new[new["90s"]>=5]
new1=new1[new1["90s"]>=5]

# %%
for i in range(new.columns.size):
    if i<=7:
        continue
    new[new.columns[i]]=new[new.columns[i]].divide(new[new.columns[7]]).round(2)

# %%
for i in range(new1.columns.size):
    if i<=7:
        continue
    new1[new1.columns[i]]=new1[new1.columns[i]].divide(new1[new1.columns[7]]).round(2)

# %%
pogurl="https://www.footyrenders.com/render/cody-gakpo-4-340x540.png"
pog=Image.open(urlopen(pogurl))
admurl="https://www.footyrenders.com/render/dusan-tadic-6-390x260.png"
admimg=Image.open(urlopen(admurl))
zieurl="https://english.ajax.nl/media/u3sdtcoe/ajax-profile-photos-ajax_0017_ajax-2022-2023-mohammed-kudus-0006.png"
zie=Image.open(urlopen(zieurl))

# %%
new[new["Player"].str.contains("Deulofeu")]

# %%
len(new1)

# %%
fig = plt.figure(figsize=(25,14))
fig.patch.set_facecolor('#E0EEEE')
fig.patch.set_alpha(0.6)
ax = fig.add_subplot(111)
ax.patch.set_facecolor('#E0EEEE')
ax.patch.set_alpha(1.0)
x=new["xA"]
y=new1["npxG"]
s3=new[(new["xA"]>0.15) & (new1["npxG"]>=0.19)]["Player"]
x3=new[(new["xA"]>0.15) & (new1["npxG"]>=0.19)]["xA"]
y3=new1[(new["xA"]>0.15) & (new1["npxG"]>=0.19)]["npxG"]
s4=new[(new["xA"]<=0.19) & (new1["npxG"]>0.3)]["Player"]
x4=new[(new["xA"]<=0.19) & (new1["npxG"]>0.3)]["xA"]
y4=new1[(new["xA"]<=0.19) & (new1["npxG"]>0.3)]["npxG"]
plt.scatter(x,y,color="cyan",edgecolor="black",label="Players in Serie A",s=90,alpha=0.3)
texts2=[]
for x3, y3, s3 in zip(x3, y3,s3):
    texts2.append(plt.text(x3, y3, s3, size=15,color="black"))
adjust_text(texts2, only_move={'points':'y', 'texts':'y'},arrowprops=dict(arrowstyle="-", color='k', lw=1),save_steps=False)
texts3=[]
for x4, y4, s4 in zip(x4, y4,s4):
    texts2.append(plt.text(x4, y4, s4, size=15,color="black"))
adjust_text(texts2, only_move={'points':'y', 'texts':'y'},arrowprops=dict(arrowstyle="-", color='k', lw=1),save_steps=False)
plt.xlabel("Expected Assists P90 (xA) ------>",color="black",fontsize=15)
plt.ylabel("Non Penalty Expected Goals (npxG) P90 ------->",color="black",fontsize=15)
plt.plot([0.08,0.14],[0.64,0.58],color="red")
plt.plot([0.29,0.32],[0.39,0.52],color="red")
plt.title("Serie A 22/23 Expected Assists (xA) vs Non Penalty Expected Goals (npxG) p90 (made by @Rahulvn5)",color="black",fontsize=25)
newax = fig.add_axes([0.1,0.15,1.5,0.18])
newax.imshow(pog)
newax.axis('off')
newax1 = fig.add_axes([0.1,0.63,0.75,0.18])
newax1.imshow(adm)
newax1.axis('off')
newax2 = fig.add_axes([0.1,0.65,1.4,0.14])
newax2.imshow(zie)
newax2.axis('off')

# %%
new=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/WC article/eredivisie passing.xlsx")
new1=pd.read_excel("C:/Users/Rahul/OneDrive/Pictures/WC article/eredivisie shooting.xlsx")

# %%
new.columns.values.tolist()

# %%
new[('Unnamed: 4_level_0', 'PSxG')]=new[('Unnamed: 4_level_0', 'PSxG')].fillna(0)

# %%
new[('Unnamed: 3_level_0', 'xG')]=new[('Unnamed: 3_level_0', 'xG')].fillna(0)

# %%
new[('Unnamed: 9_level_0', 'PSxG-xG')]=new[('Unnamed: 4_level_0', 'PSxG')]-new[('Unnamed: 3_level_0', 'xG')]

# %%
new=new.dropna(subset=[('Unnamed: 0_level_0', 'Minute')])

# %%
new

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(20, 15))
sns.set_color_codes("pastel")
sns.barplot(x=('Unnamed: 9_level_0', 'PSxG-xG'), y=('Unnamed: 1_level_0', 'Player'), data=new,
            label="PSxG-xG", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x=('Unnamed: 3_level_0', 'xG'), y=('Unnamed: 1_level_0', 'Player'), data=new,
            label="xG", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(-0.2,0.9), ylabel="Players",
       xlabel="Expected Goals")

# %%
fig = plt.figure(figsize=(25,14))
fig.patch.set_facecolor('#E0EEEE')
fig.patch.set_alpha(0.6)
ax = fig.add_subplot(111)
ax.patch.set_facecolor('#E0EEEE')
ax.patch.set_alpha(1.0)
x=new["xA"]
y=new1["npxG"]
s3=new[(new["xA"]>0.15) & (new1["npxG"]>=0.19)]["Player"]
x3=new[(new["xA"]>0.15) & (new1["npxG"]>=0.19)]["xA"]
y3=new1[(new["xA"]>0.15) & (new1["npxG"]>=0.19)]["npxG"]
s4=new[(new["xA"]<=0.19) & (new1["npxG"]>0.3)]["Player"]
x4=new[(new["xA"]<=0.19) & (new1["npxG"]>0.3)]["xA"]
y4=new1[(new["xA"]<=0.19) & (new1["npxG"]>0.3)]["npxG"]
plt.scatter(x,y,color="cyan",edgecolor="black",label="Players in Serie A",s=90,alpha=0.3)
texts2=[]
for x3, y3, s3 in zip(x3, y3,s3):
    texts2.append(plt.text(x3, y3, s3, size=15,color="black"))
adjust_text(texts2, only_move={'points':'y', 'texts':'y'},arrowprops=dict(arrowstyle="-", color='k', lw=1),save_steps=False)
texts3=[]
for x4, y4, s4 in zip(x4, y4,s4):
    texts2.append(plt.text(x4, y4, s4, size=15,color="black"))
adjust_text(texts2, only_move={'points':'y', 'texts':'y'},arrowprops=dict(arrowstyle="-", color='k', lw=1),save_steps=False)
plt.xlabel("Expected Assists P90 (xA) ------>",color="black",fontsize=15)
plt.ylabel("Non Penalty Expected Goals (npxG) P90 ------->",color="black",fontsize=15)

plt.title("Eredivisie A 22/23 Expected Assists (xA) vs Non Penalty Expected Goals (npxG) p90\n data:Fbref (made by @Rahulvn5)",color="black",fontsize=25)
newax = fig.add_axes([0.1,0.45,1.1,0.18])
newax.imshow(pog)
newax.axis('off')
newax1 = fig.add_axes([0.1,0.33,1.4,0.18])
newax1.imshow(admimg)
newax1.axis('off')
newax2 = fig.add_axes([0.1,0.72,0.3,0.14])
newax2.imshow(zie)
newax2.axis('off')
